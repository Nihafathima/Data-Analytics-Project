# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
FP = pd.read_csv(r"C:\Users\azeem\Downloads\m5_survey_data_technologies_normalised.csv")

# %%
FP.head()
# Out:
#    Respondent LanguageWorkedWith LanguageDesireNextYear DatabaseWorkedWith  \
# 0         NaN                NaN                    NaN                NaN
# 1         4.0                  C                      C              MySQL
# 2         4.0                C++                     C#             SQLite
# 3         4.0                 C#             JavaScript                NaN
# 4         4.0             Python                    SQL                NaN
#
#   DatabaseDesireNextYear PlatformWorkedWith PlatformDesireNextYear  \
# 0                    NaN                NaN                    NaN
# 1                  MySQL              Linux                  Linux
# 2                 SQLite            Windows                Windows
# 3                    NaN                NaN                    NaN
# 4                    NaN                NaN                    NaN
#
#   WebFrameWorkedWith WebFrameDesireNextYear          DevEnviron  OpSys  \
# ...

# %%
FP.tail()
# Out:
#        Respondent LanguageWorkedWith LanguageDesireNextYear  \
# 74585     25142.0                 Go                 Python
# 74586     25142.0           HTML/CSS                      R
# 74587     25142.0                PHP                    NaN
# 74588     25142.0             Python                    NaN
# 74589     25142.0                  R                    NaN
#
#       DatabaseWorkedWith DatabaseDesireNextYear PlatformWorkedWith  \
# 74585                NaN                    NaN                NaN
# 74586                NaN                    NaN                NaN
# 74587                NaN                    NaN                NaN
# 74588                NaN                    NaN                NaN
# 74589                NaN                    NaN                NaN
#
#       PlatformDesireNextYear WebFrameWorkedWith WebFrameDesireNextYear  \
# 74585                    NaN                NaN                    NaN
# ...

# %%
FP.shape
# Out:
# (74590, 14)

# %%
FP.columns
# Out:
# Index(['Respondent', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs'],
#       dtype='object')

# %%
FP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74590 entries, 0 to 74589
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              74589 non-null  float64
#  1   LanguageWorkedWith      59792 non-null  object
#  2   LanguageDesireNextYear  55764 non-null  object
#  3   DatabaseWorkedWith      31375 non-null  object
#  4   DatabaseDesireNextYear  29575 non-null  object
#  5   PlatformWorkedWith      39208 non-null  object
#  6   PlatformDesireNextYear  44314 non-null  object
#  7   WebFrameWorkedWith      24803 non-null  object
#  8   WebFrameDesireNextYear  24567 non-null  object
#  9   DevEnviron              33306 non-null  object
#  10  OpSys                   0 non-null      float64
#  11  Containers              0 non-null      float64
#  12  BlockchainOrg           0 non-null      float64
#  13  BlockchainIs            0 non-null      float64
# ...

# %%
FP.describe()
# Out:
#          Respondent  OpSys  Containers  BlockchainOrg  BlockchainIs
# count  74589.000000    0.0         0.0            0.0           0.0
# mean   12435.258228    NaN         NaN            NaN           NaN
# std     7239.729251    NaN         NaN            NaN           NaN
# min        4.000000    NaN         NaN            NaN           NaN
# 25%     6196.000000    NaN         NaN            NaN           NaN
# 50%    12422.000000    NaN         NaN            NaN           NaN
# 75%    18756.000000    NaN         NaN            NaN           NaN
# max    25142.000000    NaN         NaN            NaN           NaN

# %%
FP.isnull().sum()
# Out:
# Respondent                    1
# LanguageWorkedWith        14798
# LanguageDesireNextYear    18826
# DatabaseWorkedWith        43215
# DatabaseDesireNextYear    45015
# PlatformWorkedWith        35382
# PlatformDesireNextYear    30276
# WebFrameWorkedWith        49787
# WebFrameDesireNextYear    50023
# DevEnviron                41284
# OpSys                     74590
# Containers                74590
# BlockchainOrg             74590
# BlockchainIs              74590
# dtype: int64

# %%
FP.dtypes
# Out:
# Respondent                float64
# LanguageWorkedWith         object
# LanguageDesireNextYear     object
# DatabaseWorkedWith         object
# DatabaseDesireNextYear     object
# PlatformWorkedWith         object
# PlatformDesireNextYear     object
# WebFrameWorkedWith         object
# WebFrameDesireNextYear     object
# DevEnviron                 object
# OpSys                     float64
# Containers                float64
# BlockchainOrg             float64
# BlockchainIs              float64
# dtype: object

# %%
FP['LanguageWorkedWith'].unique()
# Out:
# array([nan, 'C', 'C++', 'C#', 'Python', 'SQL', 'Bash/Shell/PowerShell',
#        'HTML/CSS', 'JavaScript', 'Ruby', 'Rust', 'TypeScript',
#        'WebAssembly', 'Other(s):', 'PHP', 'VBA', 'Java', 'R', 'Swift',
#        'Objective-C', 'Go', 'Kotlin', 'F#', 'Erlang', 'Assembly', 'Scala',
#        'Elixir', 'Clojure', 'Dart'], dtype=object)

# %%
FP['DatabaseWorkedWith'].unique()
# Out:
# array([nan, 'MySQL', 'SQLite', 'DynamoDB', 'PostgreSQL', 'Couchbase',
#        'Firebase', 'MongoDB', 'Microsoft SQL Server', 'Elasticsearch',
#        'MariaDB', 'Oracle', 'Redis', 'Other(s):', 'Cassandra'],
#       dtype=object)

# %%
FP['PlatformWorkedWith'].unique()
# Out:
# array([nan, 'Linux', 'Windows', 'AWS', 'Docker', 'Heroku', 'MacOS',
#        'Slack', 'Android', 'IBM Cloud or Watson', 'iOS',
#        'Microsoft Azure', 'WordPress', 'Arduino', 'Raspberry Pi',
#        'Google Cloud Platform', 'Kubernetes', 'Other(s):'], dtype=object)

# %%
FP['WebFrameWorkedWith'].unique()
# Out:
# array([nan, 'Express', 'Ruby on Rails', 'Other(s):', 'Angular/Angular.js',
#        'ASP.NET', 'jQuery', 'Vue.js', 'Spring', 'React.js', 'Laravel',
#        'Drupal', 'Flask', 'Django'], dtype=object)

# %%
FP['LanguageWorkedWith'].value_counts()
# Out:
# JavaScript               8687
# HTML/CSS                 7830
# SQL                      7106
# Bash/Shell/PowerShell    4642
# Python                   4542
# Java                     4506
# C#                       4288
# TypeScript               3232
# PHP                      2913
# C++                      1946
# C                        1578
# Ruby                     1149
# Go                       1114
# Other(s):                 840
# Kotlin                    751
# Swift                     707
# VBA                       628
# R                         585
# Objective-C               518
# Scala                     492
# Assembly                  437
# Rust                      324
# Dart                      237
# Elixir                    187
# Clojure                   164
# F#                        158
# WebAssembly               133
# Erlang                     98
# Name: LanguageWorkedWith, dtype: int64

# %%
FP['DatabaseWorkedWith'].value_counts()
# Out:
# MySQL                   5469
# Microsoft SQL Server    4110
# PostgreSQL              4097
# SQLite                  3248
# MongoDB                 3016
# Redis                   2508
# Elasticsearch           1954
# Oracle                  1744
# MariaDB                 1709
# Firebase                1314
# DynamoDB                 831
# Other(s):                728
# Cassandra                397
# Couchbase                250
# Name: DatabaseWorkedWith, dtype: int64

# %%
FP.duplicated(keep='first').sum()
# Out:
# 0

# %%
FP.isnull().sum()
# Out:
# Respondent                    1
# LanguageWorkedWith        14798
# LanguageDesireNextYear    18826
# DatabaseWorkedWith        43215
# DatabaseDesireNextYear    45015
# PlatformWorkedWith        35382
# PlatformDesireNextYear    30276
# WebFrameWorkedWith        49787
# WebFrameDesireNextYear    50023
# DevEnviron                41284
# OpSys                     74590
# Containers                74590
# BlockchainOrg             74590
# BlockchainIs              74590
# dtype: int64

# %%
FP["Respondent"].duplicated(keep='first').sum()
# Out:
# 63191

# %%
plt.figure(figsize=(10,5))
sns.distplot(a=FP1["Age"],bins=20,hist=False)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
sns.distplot(a=FP1["Age"],bins=20,kde=False)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
FP["Respondent"].median()
# Out:
# 12422.0

# %%
FP1 = pd.read_csv(r"C:\Users\azeem\Downloads\m5_survey_data_demographics.csv")

# %%
FP1["Gender"].value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %%
woman = FP1[FP1["Gender"] == "Woman"]
woman["Respondent"].median()
# Out:
# 11973.0

# %%
man = FP1[FP1["Gender"] == "Woman"]
man["Respondent"].median()
# Out:
# 11973.0

# %%
FP1["Age"].describe()
# Out:
# count    11111.000000
# mean        30.779138
# std          7.393784
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=FP1.Age, data=FP1)
plt.show()

# %%
FP.corr()
# Out:
#                Respondent  OpSys  Containers  BlockchainOrg  BlockchainIs
# Respondent            1.0    NaN         NaN            NaN           NaN
# OpSys                 NaN    NaN         NaN            NaN           NaN
# Containers            NaN    NaN         NaN            NaN           NaN
# BlockchainOrg         NaN    NaN         NaN            NaN           NaN
# BlockchainIs          NaN    NaN         NaN            NaN           NaN

# %%
FP1.corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.013490       0.002181    -0.015314    0.004621
# CompTotal       -0.013490   1.000000       0.001037     0.003510    0.007063
# ConvertedComp    0.002181   0.001037       1.000000     0.021143   -0.033865
# WorkWeekHrs     -0.015314   0.003510       0.021143     1.000000    0.026517
# CodeRevHrs       0.004621   0.007063      -0.033865     0.026517    1.000000
# Age              0.004068   0.006968       0.105418     0.036521   -0.020478
#
#                     Age
# Respondent     0.004068
# CompTotal      0.006968
# ConvertedComp  0.105418
# WorkWeekHrs    0.036521
# CodeRevHrs    -0.020478
# Age            1.000000

# %%
FP1["ConvertedComp"].describe()
# Out:
# count    1.058200e+04
# mean     1.315967e+05
# std      2.947865e+05
# min      0.000000e+00
# 25%      2.686800e+04
# 50%      5.774500e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
Q1 = FP1["ConvertedComp"].quantile(0.25)
Q3 = FP1["ConvertedComp"].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 73132.0

# %%
outliers = (FP1["ConvertedComp"] < (Q1 - 1.5 * IQR)) | (FP1["ConvertedComp"] > (Q3 + 1.5 * IQR))
outliers.value_counts()
less = (FP1["ConvertedComp"] < (Q1 - 1.5 * IQR))
less.value_counts()
more = (FP1["ConvertedComp"] > (Q3 + 1.5 * IQR))
more.value_counts()
# Out:
# False    10519
# True       879
# Name: ConvertedComp, dtype: int64

# %%
FP
# Out:
#        Respondent LanguageWorkedWith LanguageDesireNextYear  \
# 0             NaN                NaN                    NaN
# 1             4.0                  C                      C
# 2             4.0                C++                     C#
# 3             4.0                 C#             JavaScript
# 4             4.0             Python                    SQL
# ...           ...                ...                    ...
# 74585     25142.0                 Go                 Python
# 74586     25142.0           HTML/CSS                      R
# 74587     25142.0                PHP                    NaN
# 74588     25142.0             Python                    NaN
# 74589     25142.0                  R                    NaN
#
#       DatabaseWorkedWith DatabaseDesireNextYear PlatformWorkedWith  \
# 0                    NaN                    NaN                NaN
# 1                  MySQL                  MySQL              Linux
# ...

# %%
FP1
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11393       25136  I am a developer by profession      Yes
# 11394       25137  I am a developer by profession      Yes
# 11395       25138  I am a developer by profession      Yes
# 11396       25141  I am a developer by profession      Yes
# 11397       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...
